# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawhidrahman292/Roadmap-Docs/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install -q -U matplotlib seaborn pandas scikit-learn

# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# Load the Socio economic factors and income dataset
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/Datasets/sgdata.csv')
# Out:
# Mounted at /content/drive

# %%
# Show the first few rows of the dataset
df.head()

# Explore the dataset - check for missing values and basic info
df.info()

# Check for null values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2000 non-null   int64
#  1   Sex              2000 non-null   int64
#  2   Marital status   2000 non-null   str
#  3   Age              2000 non-null   int64
#  4   Education        2000 non-null   str
#  5   Income           2000 non-null   int64
#  6   Occupation       2000 non-null   str
#  7   Settlement size  2000 non-null   int64
# dtypes: int64(5), str(3)
# memory usage: 263.7 KB
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %%
#Selecting relevant columns for clustering (Education)
le = LabelEncoder()
df['Education'] = le.fit_transform(df['Education'])

features = ['Age','Income','Education']
X = df[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# --- K-Means Clustering ---
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster_KMeans'] = kmeans.fit_predict(X_scaled)

df['Cluster_KMeans'].value_counts()

# Visualize the K-Means clusters

plt.figure(figsize=(8,6))

sns.scatterplot(
    x=df['Age'],
    y=df['Income'],
    hue=df['Cluster_KMeans'],   # তোমার cluster column
    palette='viridis',
    s=100
)

plt.title('K-Means Clustering (Age vs Income)')
plt.xlabel('Age')
plt.ylabel('Income')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# scaled data থেকে ৫০টা sample নাও
sample_data = X_scaled[:50]

# linkage matrix
linked = linkage(sample_data, method='ward')

# dendrogram plot
plt.figure(figsize=(8,5))
dendrogram(
    linked,
    truncate_mode='level',
    p=5,
    color_threshold=3
)

plt.title('Simplified Dendrogram (First 50 Samples)')
plt.xlabel('Sample Index')
plt.ylabel('Euclidean Distance')
plt.show()

# %%
# Apply Agglomerative Clustering (Hierarchical) with k=5
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

hierarchical = AgglomerativeClustering(n_clusters=5, linkage='ward')
y_hc = hierarchical.fit_predict(X_scaled)

# Plot comparison
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,7))

# --- K-Means plot ---
ax1.scatter(df['Age'], df['Income'], c=df['Cluster_KMeans'], cmap='viridis', s=100)
ax1.set_title('K-Means Clustering (k=5)')
ax1.set_xlabel('Age')
ax1.set_ylabel('Income')

# --- Hierarchical plot ---
ax2.scatter(df['Age'], df['Income'], c=y_hc, cmap='viridis', s=100)
ax2.set_title('Hierarchical Clustering (k=5)')
ax2.set_xlabel('Age')
ax2.set_ylabel('Income')

plt.tight_layout()
plt.show()

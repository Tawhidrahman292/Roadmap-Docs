# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawhidrahman292/Roadmap-Docs/blob/main/class4_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  numpy as np
arr = np.array([2,4,6,8,9,10,12,13,14,15,16,17,18,19,20,23,24,25,26,27])
print("Array:",arr)
print("sum:",np.sum(arr))
print("max value:",np.max(arr))
print("min value:",np.min(arr))
# Out:
# Array: [ 2  4  6  8  9 10 12 13 14 15 16 17 18 19 20 23 24 25 26 27]
# sum: 308
# max value: 27
# min value: 2

# %%
import numpy as np
import pandas as pd


data = np.random.randint(1, 100, size=(5, 3))
df = pd.DataFrame(data, columns=['A', 'B', 'C'])

print("DataFrame:\n", df)


print("\nColumn-wise Sum:\n", df.sum())

print("\nColumn-wise Mean:\n", df.mean())
# Out:
# DataFrame:
#      A   B   C
# 0  86  64  43
# 1  65  30  19
# 2  58  87  44
# 3  37  73   1
# 4  60  60  66
#
# Column-wise Sum:
#  A    306
# B    314
# C    173
# dtype: int64
#
# Column-wise Mean:
#  A    61.2
# B    62.8
# C    34.6
# dtype: float64
